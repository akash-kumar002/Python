# %%
z=[11,22,33,44,55,"ak",2.2]
z.append(66)
print(z)
# Out:
# [11, 22, 33, 44, 55, 'ak', 2.2, 66]

# %%
z.extend([77,88,99,"akash"])
print(z)
# Out:
# [11, 22, 33, 44, 55, 'ak', 2.2, 66, 77, 88, 99, 'akash']

# %%
z.insert(7,100)
print(z)
# Out:
# [11, 22, 33, 44, 55, 'ak', 2.2, 100, 66, 77, 88, 99, 'akash']

# %%
z.remove(99)
print(z)
# Out:
# [11, 22, 33, 44, 55, 'ak', 2.2, 100, 66, 77, 88, 'akash']

# %%
z.pop(0)
print(z)
# Out:
# [22, 33, 44, 55, 'ak', 2.2, 100, 66, 77, 88, 'akash']

# %%
print(z.index("akash"))
# Out:
# 10

# %%
print(z.count(22))
# Out:
# 1

# %%
z.copy
x=z.copy()
print(x)
# Out:
# [22, 33, 44, 55, 'ak', 2.2, 100, 66, 77, 88, 'akash']

# %%
x.clear()
print(x)
# Out:
# []

# %%
akash =(11,"ak",1.1,True,22)
print(akash)
# Out:
# (11, 'ak', 1.1, True, 22)

# %%
len.akash()
print(akash)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1974/183627910.py in <cell line: 0>()
# ----> 1 len.akash()
#       2 print(akash)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'akash'

# %%
print(len(akash))

# %%
print(max(akash))

# %%
number=(11,22,33,44,55,66)
print("tuple",number)
print("lenght",len(number))
print(min(number))
print(max(number))
print(number.index(44))

# %%
l1=[11,22,33,44,55]
l2=[10,12,13,14,15]
print(l1[0]+l1[1]+l1[2]+l1[3]+l2[4])
print(l1+l2)
# Out:
# 125
# [11, 22, 33, 44, 55, 10, 12, 13, 14, 15]

# %%
t1=(11,22,33,44,55,)
t2=(10,12,13,14,15)
print(t1[0]+t1[1]+t1[2]+t1[3]+t1[4])
print(t1+t2)
# Out:
# 165
# (11, 22, 33, 44, 55, 10, 12, 13, 14, 15)

# %%
from sys import addaudithook
set1={11,22,33,44,55}
set1.add(66)
print(set1)
# Out:
# {33, 66, 22, 55, 11, 44}

# %%
set1.update([18,20,33])
print(set1)
# Out:
# {33, 66, 18, 20, 22, 55, 11, 44}

# %%
set1.remove(55)
print(set1)
# Out:
# {33, 66, 18, 20, 22, 11, 44}

# %%
set1.discard(12)
print(set1)
# Out:
# {33, 66, 18, 20, 22, 11, 44}

# %%
set1.pop(20)
print(set1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1115/2509637589.py in <cell line: 0>()
# ----> 1 set1.pop(20)
#       2 print(set1)
#
# TypeError: set.pop() takes no arguments (1 given)
